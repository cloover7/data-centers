# %%
import numpy as np
import pandas as pd

# %%
centers = pd.read_csv('data/data_centers/data_centers.csv')
timelines = pd.read_csv('data/data_centers/data_center_timelines.csv')

# %%
centers.head()
# Out:
#                                               Handle  \
# 0                          Amazon Canton Mississippi
# 1                       Amazon Ridgeland Mississippi
# 2  Anthropic-Amazon Project Rainier New Carlisle ...
# 3                             Crusoe Goodnight Texas
# 4                             Google New Albany Ohio
#
#                            Title                       Project  \
# 0       Amazon Madison Mega Site  Project Rainier #speculative
# 1               Amazon Ridgeland  Project Rainier #speculative
# 2  Anthropic-Amazon New Carlisle    Project Rainier #confident
# 3                      Goodnight                           NaN
# 4              Google New Albany                           NaN
#
#                         Sentinel satellite timelapse  \
# 0  [{'id': 'atteIsn2EcnSUJMCI', 'width': 512, 'he...
# 1  [{'id': 'attYoPvBtA5CoXEUh', 'width': 512, 'he...
# 2  [{'id': 'attzRv49wzPJAeNy2', 'width': 512, 'he...
# ...

# %%
timelines.head()
# Out:
#          Date                Data center  \
# 0  2023-10-02  Amazon Canton Mississippi
# 1  2025-03-11  Amazon Canton Mississippi
# 2  2025-06-23  Amazon Canton Mississippi
# 3  2025-10-04  Amazon Canton Mississippi
# 4  2026-09-18  Amazon Canton Mississippi
#
#                                  Construction status  Power (MW)  \
# 0                               Land clearing begins         0.0
# 1  Generators and chillers still being installed ...         0.0
# 2  Buildings 1-5 are operational, based on roofs ...       341.0
# 3  Confirmation that five buildings are fully equ...       341.0
# 4  Buildings 1-12 are operational. The outline of...       819.0
#
#    H100 equivalents  Buildings operational  \
# 0          0.000000                      0
# 1          0.000000                      0
# 2     214348.143546                      5
# 3     214348.143546                      5
# 4     514435.544509                     12
#
# ...
